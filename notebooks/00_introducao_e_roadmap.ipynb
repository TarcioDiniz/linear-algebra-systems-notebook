# %% [markdown]
# <div align="center">
#   <img src="../assets/uepb_logo.png" width="150">
#   <br>
#   <strong>Universidade Estadual da Paraíba (UEPB)</strong><br>
#   <strong>Professor(a):</strong> Thiciany Matsudo Iwano<br>
#   <strong>Alunos:</strong> Tarcio Elyakin Agra Diniz & Djhonatah Wesley Cavalcanti Alves<br>
#   <strong>Série:</strong> Sistemas Lineares: teoria, interpretação geométrica e aplicações com Python<br>
# </div>
#
# ---
#
# # [Tutorial 00] Introdução e Roadmap: Sistemas Lineares com Python
#
# > **Próximo:** [01] Conceitos Básicos e Visualização 2D (`01_conceitos_basicos_e_visualizacao_2d.ipynb`)
#
# ---
#
# ## 1. Bem-vindo ao Tutorial de Sistemas Lineares!
#
# Seja você um estudante de engenharia, ciência da computação ou alguém apaixonado por matemática aplicada, este tutorial foi desenhado para transformar conceitos abstratos de sistemas lineares em ferramentas práticas e compreensíveis.
#
# Sistemas lineares são o coração da Álgebra Linear. Eles não são apenas equações no papel; eles são a linguagem que descreve o fluxo de tráfego em uma cidade, a distribuição de corrente em um circuito elétrico e o ajuste de modelos complexos em inteligência artificial.
#
# ### O que você vai aprender?
# Nesta jornada, uniremos três pilares fundamentais:
# 1. **Rigor Acadêmico:** Teoria e definições precisas.
# 2. **Intuição Geométrica:** O que as equações significam visualmente.
# 3. **Prática Computacional:** Como resolver e automatizar processos usando **Python**.
#
# ---
#
# ## 2. Ferramentas Utilizadas
#
# Para aproveitar ao máximo este conteúdo, utilizaremos as bibliotecas mais potentes do ecossistema Python:
#
# - **NumPy:** O padrão ouro para computação numérica e matrizes.
# - **SymPy:** Para álgebra simbólica (resoluções exatas e frações).
# - **Matplotlib/Seaborn:** Para dar vida às equações com gráficos 2D e 3D.
# - **NetworkX:** Para visualizar e modelar redes de fluxo.
#
# ---
#
# ## 3. Roteiro de Estudo (Roadmap)
#
# Siga a ordem sugerida para garantir uma curva de aprendizado suave. Cada etapa prepara o terreno para a próxima.
#
# | Ordem | Tutorial | Objetivo Principal |
# | :--- | :--- | :--- |
# | 1 | **[01] Conceitos Básicos** | Definições, forma $Ax=b$ e visualização em 2D. |
# | 2 | **[02] Matriz Aumentada** | Como organizar sistemas para o computador. |
# | 3 | **[03] Métodos de Resolução** | Algoritmos de Gauss e Gauss-Jordan (RREF). |
# | 4 | **[04] Geometria & LI/LD** | O que acontece no espaço 3D? Vetores LI e LD. |
# | 5 | **[05] Transformações** | O sistema como uma função: Núcleo e Imagem. |
# | 6 | **[06] Aplicação: Tráfego** | Modelagem de fluxo em malhas urbanas reais. |
# | 7 | **[07] Aplicação: Interpolação** | Criando curvas que passam por pontos específicos. |
# | 8 | **[08] Prática Sugerida** | Exercícios para testar seus novos conhecimentos. |
# | 9 | **[09] Conclusão** | Próximos passos e bibliografia recomendada. |
#
# ---
#
# ## 4. Exemplo Motivador: A Simplicidade do Python
#
# Para começar, veja como o Python resolve instantaneamente um problema que levaria tempo no papel.
#
# **O Desafio:** "A soma de dois números é 10 e a diferença entre eles é 2. Quais são esses números?"
# Em matemática, temos:
# $$
# \begin{cases}
# x + y = 10 \\
# x - y = 2
# \end{cases}
# $$
#
# Observe o código abaixo para ver a solução numérica e visual:

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuração do Seaborn para gráficos mais bonitos
sns.set_theme(style="whitegrid", palette="muted")

# 1. Definindo as matrizes do sistema Ax = b
A = np.array([[1, 1], 
              [1, -1]])
b = np.array([10, 2])

# 2. Resolvendo o sistema
x_sol = np.linalg.solve(A, b)
print(f"Solução encontrada: x = {x_sol[0]}, y = {x_sol[1]}")

# 3. Visualização com Seaborn
x_vals = np.linspace(0, 10, 100)
y1 = 10 - x_vals
y2 = x_vals - 2

plt.figure(figsize=(8, 5))
sns.lineplot(x=x_vals, y=y1, label='x + y = 10', linewidth=2)
sns.lineplot(x=x_vals, y=y2, label='x - y = 2', linewidth=2)

# Destacando a solução
plt.scatter(x_sol[0], x_sol[1], color='red', s=100, zorder=5, edgecolor='white', label=f'Interseção {x_sol}')

# Ajustes estéticos finais
plt.axhline(0, color='black', lw=0.8, alpha=0.5)
plt.axvline(0, color='black', lw=0.8, alpha=0.5)
plt.title("Visualização do Sistema 2x2", fontsize=14, pad=15)
plt.xlabel("x", fontsize=12)
plt.ylabel("y", fontsize=12)
plt.legend(frameon=True, shadow=True)
sns.despine()
plt.tight_layout()
plt.show()
# Out:
# Solução encontrada: x = 6.0, y = 4.0

# %% [markdown]
# ---
# ## Próximo Passo
#
# Agora que você conhece o mapa, vamos começar pela base!
#
# 👉 **[Ir para o Tutorial 01: Conceitos Básicos e Visualização 2D](./01_conceitos_basicos_e_visualizacao_2d.ipynb)**
